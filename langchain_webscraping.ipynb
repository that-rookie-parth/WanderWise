# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright
from langchain.chains import create_extraction_chain

# %%
async def run_playwright(site):
    data = ""
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)

        page = await browser.new_page()
        await page.goto(site)

        page_source = await page.content()
        soup = BeautifulSoup(page_source, "html.parser")
        
        for script in soup(["script", "style"]): # remove all javascript and stylesheet code
            script.extract()
        # get text
        text = soup.get_text()
        # break into lines and remove leading and trailing space on each
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        # drop blank lines
        data = '\n'.join(chunk for chunk in chunks if chunk)

        await browser.close()
    return data

output = await run_playwright("https://www.youtube.com/@tylerwhatsgood/videos")

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613")
structured_schema = {
    "properties": {
        "video_name": {"type": "string"},
        "views": {"type": "integer"},
    },
    "required": ["video_name", "views"],
}
extraction_chain = create_extraction_chain(structured_schema, llm)
extraction_chain.run(output)
# Out:
# /home/kparth/anaconda3/envs/genAI/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# /home/kparth/anaconda3/envs/genAI/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# [{'video_name': 'Insanely Fast LLM (400+ tokens/second !!)', 'views': 900},
#  {'video_name': 'CrewAI Agents for Stock Analysis (Works with Local Ollama LLMs!)',
#   'views': 10000},
#  {'video_name': 'All Sora Videos with Prompts', 'views': 125},
#  {'video_name': "OpenAI's Sora is Overpowered (Text-to-video Generator)",
#   'views': 238},
#  {'video_name': 'Google Releases Gemini', 'views': 654},
#  {'video_name': 'The OpenAI Drama Is Finally Over', 'views': 654},
#  {'video_name': 'OpenAI Fires CEO', 'views': 446},
#  {'video_name': 'Cursor AI Editor Is Overpowered', 'views': 4500},
#  {'video_name': 'Locally Run ChatGPT Code Interpreter with Open Interpreter',
#   'views': 696},
#  {'video_name': 'Use AI To Make Money with Python - Scraping and Extracting Data',
#   'views': 18000},
#  {'video_name': 'How to Scrape and Extract Data with Langchain GPT Function Calling',
#   'views': 9500},
#  {'video_name': 'GPT-Engineer Builds Entire Apps With One Prompt',
#   'views': 1300},
#  {'video_name': 'GPT-Engineer BUILDS ENTIRE GAME With Single Prompt',
#   'views': 3000},
#  {'video_name': 'Vercel AI SDK is Overpowered | Nextjs + Supabase',
#   'views': 2400},
#  {'video_name': 'How To Use GPT-4 Function Calling', 'views': 811},
#  {'video_name': 'NEW Text to Video, MiniGPT-4 🤖 Elon suing Microsoft',
#   'views': 1000},
#  {'video_name': 'ChatGPT Texts My Girlfriend (Langchain + GPT-4)',
#   'views': 762},
#  {'video_name': 'How To Use Auto-GPT In Your Browser (AgentGPT) GPT-4',
#   'views': 1400},
#  {'video_name': 'BabyAGI + GPT-4 Langchain Agent with Internet Access',
#   'views': 13000},
#  {'video_name': 'This is The End of Writing Code 🤯 OpenAI GPT-4 Cataclysm Python Tutorial',
#   'views': 9700},
#  {'video_name': 'How to create ChatGPT with Langchain OpenAI Nextjs Javascript',
#   'views': 4600},
#  {'video_name': 'How to Talk To A Video with LLMs and Javascript: QA with ChatGPT Langchain Supabase Embeddings',
#   'views': 2400},
#  {'video_name': 'How to Make Your Own Custom ChatGPT With Internet Access + Memory Tutorial',
#   'views': 5300},
#  {'video_name': 'AI CAN SEARCH THE INTERNET?\nLangchain Agents + OpenAI ChatGPT',
#   'views': 8900},
#  {'video_name': 'How to use GPT-3 or ChatGPT to Q&A Custom Data with OpenAI Embeddings API',
#   'views': 2600}]

# %%
async def run_playwright(site):
    data = ""
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)

        page = await browser.new_page()
        await page.goto(site)

        page_source = await page.content()
        soup = BeautifulSoup(page_source, "html.parser")

        for script in soup(["script", "style"]): # remove all javascript and stylesheet code
            script.extract()
        # get text
        text = soup.get_text()
        # break into lines and remove leading and trailing space on each
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        # drop blank lines
        data = '\n'.join(chunk for chunk in chunks if chunk)

        await browser.close()
    return data

# %%
output = await run_playwright("https://www.futuretools.io/")

# %%
output
# Out:
# 'Future Tools - Find The Exact AI Tool For Your Needs\nHomeAdded TodayAI NewsVideosHelpGlossaryFAQSubmit A Tool\n"FutureTools Collects & Organizes All The Best AI Tools So YOU Too Can Become Superhuman!"AI DetectionAggregators AvatarChatCopywritingFinanceFor FunGamingGenerative ArtGenerative CodeGenerative VideoImage ImprovementImage ScanningInspirationMarketingMotion CaptureMusicPodcastingProductivityPrompt GuidesResearchSelf-ImprovementSocial MediaSpeech-To-TextText-To-SpeechText-To-VideoTranslationVideo EditingVoice ModulationThank you! Your submission has been received!Oops! Something went wrong while submitting the form.FreeFreemiumGitHubGoogle ColabOpen SourcePaidThank you! Your submission has been received!Oops! Something went wrong while submitting the form.Matt\'s PicksSpecial OfferThank you! Your submission has been received!Oops! Something went wrong while submitting the form.Showing100ofXTotal Tools.Sort (Default - Newest)Most UpvotedSort By Name (A-Z)Sort By Name (Z-A)Date Added (Newest-Oldest)Date Added (Oldest-Newest)Thank you! Your submission has been received!Oops! Something went wrong while submitting the form.TubeBuddyYouTube optimization and SEO toolFeatured ListingGuiddeA tool to create video documentations.Featured ListingRetrovision AppA tool to create depth-maps from imagesGenerative Art111MarkeroA platform to automate digital marketing tasks with content creation and lead management.Marketing111DashworksA tool to access unified organizational knowledge base.Productivity111Infinite CraftA tool to combine elemental basics to discover new alchemical creations.For Fun555GeoSpy.aiA tool to analyze and interprets satellite imagery and spatial data.AI Detection333EverArtA tool for creating, organizing, and managing styled images.Generative Art222CubbyA tool tool to organize and annotate content for research collaboration with synthesis.Research444WizardshotA tool to automate the creation of step-by-step tutorials by capturing on-screen actions.Productivity111Secret LlamaA locally-run chatbot for private conversations.Chat222HyperaideA tool for task management and productivity.Productivity111TragA tool to auto review code and suggest fixes based on custom natural language rules.Generative Code353535Ilus AIA tool to generate custom, stylistically consistent illustrations.Generative Art666PodifyA tool for networking to create and engage with niche micro-communities.Social Media333Amazon QA tool to automate software development and analyze company data.Generative Code444BahamaA tool to automate knowledge-based tasks with personalized AI assistants.Productivity555KerligA writing and communication assistant for across MacOS.Productivity555Brainy DocsA tool to turn PDFs into explainer videos.Text-To-Video161616Wikipedia Article AIA tool to generate guideline-compliant Wikipedia articles.Marketing444CountA tool to automate accounting processes for financial management.Finance999AI Logo MakerA tool to generate custom logos.Generative Art777Next PageLoading Even More!Grab Free Access To TheAI Income Database!We respect your email inbox and will never spam!© 2023 FutureTools.io. All rights reservedBuilt by Matt WolfeTerms Of UsePrivacy Policy'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613")

structured_schema = {
    "properties": {
        "product": {"type": "string"},
        "description": {"type": "string"},
    },
    "required": ["product", "description"],
}
extraction_chain = create_extraction_chain(structured_schema, llm)
extraction_chain.run(output)
# Out:
# [{'product': 'TubeBuddy', 'description': 'YouTube optimization and SEO tool'},
#  {'product': 'Guidde', 'description': 'A tool to create video documentations'},
#  {'product': 'Retrovision App',
#   'description': 'A tool to create depth-maps from images'},
#  {'product': 'Markero',
#   'description': 'A platform to automate digital marketing tasks with content creation and lead management'},
#  {'product': 'Dashworks',
#   'description': 'A tool to access unified organizational knowledge base'},
#  {'product': 'Infinite Craft',
#   'description': 'A tool to combine elemental basics to discover new alchemical creations'},
#  {'product': 'GeoSpy.ai',
#   'description': 'A tool to analyze and interprets satellite imagery and spatial data'},
#  {'product': 'EverArt',
#   'description': 'A tool for creating, organizing, and managing styled images'},
#  {'product': 'Cubby',
#   'description': 'A tool to organize and annotate content for research collaboration with synthesis'},
#  {'product': 'Wizardshot',
#   'description': 'A tool to automate the creation of step-by-step tutorials by capturing on-screen actions'},
#  {'product': 'Secret Llama',
#   'description': 'A locally-run chatbot for private conversations'},
#  {'product': 'Hyperaide',
#   'description': 'A tool for task management and productivity'},
#  {'product': 'Trag',
#   'description': 'A tool to auto review code and suggest fixes based on custom natural language rules'},
#  {'product': 'Ilus AI',
#   'description': 'A tool to generate custom, stylistically consistent illustrations'},
#  {'product': 'Podify',
#   'description': 'A tool for networking to create and engage with niche micro-communities'},
#  {'product': 'Amazon QA',
#   'description': 'A tool to automate software development and analyze company data'},
#  {'product': 'Bahama',
#   'description': 'A tool to automate knowledge-based tasks with personalized AI assistants'},
#  {'product': 'Kerlig',
#   'description': 'A writing and communication assistant for across MacOS'},
#  {'product': 'Brainy Docs',
#   'description': 'A tool to turn PDFs into explainer videos'},
#  {'product': 'Wikipedia Article AI',
#   'description': 'A tool to generate guideline-compliant Wikipedia articles'},
#  {'product': 'Count',
#   'description': 'A tool to automate accounting processes for financial management'},
#  {'product': 'AI Logo Maker',
#   'description': 'A tool to generate custom logos'}]

# %%
async def run_playwright(site):
    data = ""
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)

        page = await browser.new_page()
        await page.goto(site)

        page_source = await page.content()
        soup = BeautifulSoup(page_source, "html.parser")

        for script in soup(["script", "style"]): # remove all javascript and stylesheet code
            script.extract()
        # get text
        text = soup.get_text()
        # break into lines and remove leading and trailing space on each
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        # drop blank lines
        data = '\n'.join(chunk for chunk in chunks if chunk)

        await browser.close()
    return data

output = await run_playwright("https://news.ycombinator.com/news")

# %%
output
# Out:
# 'Hacker News\nHacker News\nnew | past | comments | ask | show | jobs | submit\nlogin\n1. AlphaFold 3 predicts the structure and interactions of life\'s molecules (blog.google)\n876 points by zerojames 15 hours ago\n| hide | 387\xa0comments\n2. Disaster Recovery with ZFS and Zrepl (chromakode.com)\n8 points by aargh_aargh 46 minutes ago\n| hide | discuss\n3. Consistency LLM: converting LLMs to parallel decoders accelerates inference 3.5x (hao-ai-lab.github.io)\n323 points by zhisbug 10 hours ago\n| hide | 67\xa0comments\n4. Temporal Python – A durable, distributed asyncio event loop (2023) (temporal.io)\n37 points by metadat 4 hours ago\n| hide | 2\xa0comments\n5. Symbolica Computer Algebra System (symbolica.io)\n17 points by weinzierl 3 hours ago\n| hide | 8\xa0comments\n6. The Time I Lied to the CTO and Saved the Day (grumpyolddev.com)\n218 points by mundanerality 5 hours ago\n| hide | 153\xa0comments\n7. Show HN: Tegon: AI-first open source alternative to Jira and Linear (github.com/tegonhq)\n35 points by harshithmul 5 hours ago\n| hide | 7\xa0comments\n8. Industrial Design Student Work: "How Long Should Objects Last?" (core77.com)\n108 points by surprisetalk 10 hours ago\n| hide | 60\xa0comments\n9. Opening Windows in Linux with sockets, bare hands and 200 lines of C (hereket.com)\n75 points by libcheet 7 hours ago\n| hide | 24\xa0comments\n10. An Unusual Furniture Design Niche: Behind-the-Sofa Consoles (core77.com)\n14 points by surprisetalk 3 hours ago\n| hide | 5\xa0comments\n11. TimesFM: Time Series Foundation Model for time-series forecasting (github.com/google-research)\n245 points by yeldarb 17 hours ago\n| hide | 81\xa0comments\n12. How to Use the Foreign Function API in Java 22 to Call C Libraries (ifesunmola.com)\n170 points by pjmlp 15 hours ago\n| hide | 101\xa0comments\n13. Development Notes from xkcd\'s "Machine" (chromakode.com)\n492 points by chromakode 13 hours ago\n| hide | 63\xa0comments\n14. Show HN: AI climbing coach – visualize how to climb any route based on your body (climbing.ai)\n236 points by smandava 18 hours ago\n| hide | 114\xa0comments\n15. Breathwork supports emergence of altered states of consciousness (researchsquare.com)\n91 points by rendx 10 hours ago\n| hide | 28\xa0comments\n16. Show HN: I built a non-linear UI for ChatGPT (grafychat.com)\n318 points by setnone 14 hours ago\n| hide | 88\xa0comments\n17. Bringing psql’s \\d to your web browser (neon.tech)\n48 points by gmac 10 hours ago\n| hide | 22\xa0comments\n18. Securing Git Repositories with Gittuf (lwn.net)\n30 points by chmaynard 8 hours ago\n| hide | 3\xa0comments\n19. Radius Full Page Display (32by32.com)\n70 points by mikerg87 9 hours ago\n| hide | 26\xa0comments\n20. Show HN: SimBricks – Modular Full-System Simulation for HW-SW Systems (simbricks.github.io)\n40 points by antoine-kaufm 7 hours ago\n| hide | 2\xa0comments\n21. Stack Overflow users deleting answers after OpenAI partnership (build5nines.com)\n229 points by miles 9 hours ago\n| hide | 234\xa0comments\n22. The Waning Reign of the Muskrat (hakaimagazine.com)\n108 points by Thevet 16 hours ago\n| hide | 22\xa0comments\n23.\nEmpirical Health (YC S23) is hiring engineering leads in NYC (ycombinator.com)\n9 hours ago | hide\n24. Launch HN: Baselit (YC W23) – Automatically Reduce Snowflake Costs\n42 points by sahil_singla 14 hours ago\n| hide | 25\xa0comments\n25. Pulley system composition – a systematic approach (2020) (kiipeilytuomas.fi)\n45 points by timjver 11 hours ago\n| hide | 8\xa0comments\n26. Japanese Trade Publications Helped Japan Form a New Graphic Identity (2023) (collectorsweekly.com)\n68 points by prismatic 14 hours ago\n| hide | 2\xa0comments\n27. Using AirPods as a Morse Transmitter (github.com/etherdream)\n141 points by etherdream 17 hours ago\n| hide | 32\xa0comments\n28. The Birth of Parquet (sympathetic.ink)\n90 points by whinvik 17 hours ago\n| hide | 49\xa0comments\n29. \'Underwater bicycle\' propels swimmers forward at superhuman speed (newatlas. ...

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613")
structured_schema = {
    "properties": {
        "name": {"type": "string"},
        "points": {"type": "integer"},
        "comments": {"type": "integer"},
        "url": {"type":"string"}
    },
    "required": ["name", "points", "comments"],
}
extraction_chain = create_extraction_chain(structured_schema, llm)
extraction_chain.run(output)
# Out:
# [{'name': 'AlphaFold 3', 'points': 876, 'comments': 387, 'url': 'blog.google'},
#  {'name': 'Disaster Recovery with ZFS and Zrepl',
#   'points': 8,
#   'comments': 0,
#   'url': 'chromakode.com'},
#  {'name': 'Consistency LLM',
#   'points': 323,
#   'comments': 67,
#   'url': 'hao-ai-lab.github.io'},
#  {'name': 'Temporal Python',
#   'points': 37,
#   'comments': 2,
#   'url': 'temporal.io'},
#  {'name': 'Symbolica Computer Algebra System',
#   'points': 17,
#   'comments': 8,
#   'url': 'symbolica.io'},
#  {'name': 'The Time I Lied to the CTO and Saved the Day',
#   'points': 218,
#   'comments': 153,
#   'url': 'grumpyolddev.com'},
#  {'name': 'Tegon', 'points': 35, 'comments': 7, 'url': 'github.com/tegonhq'},
#  {'name': 'Industrial Design Student Work',
#   'points': 108,
#   'comments': 60,
#   'url': 'core77.com'},
#  {'name': 'Opening Windows in Linux with sockets, bare hands and 200 lines of C',
#   'points': 75,
#   'comments': 24,
#   'url': 'hereket.com'},
#  {'name': 'An Unusual Furniture Design Niche',
#   'points': 14,
#   'comments': 5,
#   'url': 'core77.com'},
#  {'name': 'TimesFM',
#   'points': 245,
#   'comments': 81,
#   'url': 'github.com/google-research'},
#  {'name': 'How to Use the Foreign Function API in Java 22 to Call C Libraries',
#   'points': 170,
#   'comments': 101,
#   'url': 'ifesunmola.com'},
#  {'name': 'Development Notes from xkcd\'s "Machine"',
#   'points': 492,
#   'comments': 63,
#   'url': 'chromakode.com'},
#  {'name': 'AI climbing coach',
#   'points': 236,
#   'comments': 114,
#   'url': 'climbing.ai'},
#  {'name': 'Breathwork supports emergence of altered states of consciousness',
#   'points': 91,
#   'comments': 28,
#   'url': 'researchsquare.com'},
#  {'name': 'I built a non-linear UI for ChatGPT',
#   'points': 318,
#   'comments': 88,
#   'url': 'grafychat.com'},
#  {'name': 'Bringing psql’s \\d to your web browser',
#   'points': 48,
#   'comments': 22,
#   'url': 'neon.tech'},
#  {'name': 'Securing Git Repositories with Gittuf',
#   'points': 30,
#   'comments': 3,
#   'url': 'lwn.net'},
#  {'name': 'Radius Full Page Display',
#   'points': 70,
#   'comments': 26,
#   'url': '32by32.com'},
#  {'name': 'SimBricks',
#   'points': 40,
#   'comments': 2,
#   'url': 'simbricks.github.io'},
#  {'name': 'Stack Overflow users deleting answers after OpenAI partnership',
#   'points': 229,
#   'comments': 234,
#   'url': 'build5nines.com'},
#  {'name': 'The Waning Reign of the Muskrat',
#   'points': 108,
#   'comments': 22,
#   'url': 'hakaimagazine.com'},
#  {'name': 'Empirical Health',
#   'points': 0,
#   'comments': 0,
#   'url': 'ycombinator.com'},
#  {'name': 'Baselit', 'points': 42, 'comments': 25, 'url': 'sahil_singla'},
#  {'name': 'Pulley system composition',
#   'points': 45,
#   'comments': 8,
#   'url': 'kiipeilytuomas.fi'},
#  {'name': 'Japanese Trade Publications Helped Japan Form a New Graphic Identity',
#   'points': 68,
#   'comments': 2,
#   'url': 'collectorsweekly.com'},
#  {'name': 'Using AirPods as a Morse Transmitter',
#   'points': 141,
#   'comments': 32,
#   'url': 'github.com/etherdream'},
#  {'name': 'The Birth of Parquet',
#   'points': 90,
#   'comments': 49,
#   'url': 'sympathetic.ink'},
#  {'name': "'Underwater bicycle' propels swimmers forward at superhuman speed",
#   'points': 458,
#   'comments': 239,
#   'url': 'newatlas.com'},
#  {'name': 'OpenAI: Model Spec',
#   'points': 83,
#   'comments': 145,
#   'url': 'openai.com'}]

# %%
async def run_playwright(site):
    data = ""
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)

        page = await browser.new_page()
        await page.goto(site)

        page_source = await page.content()
        soup = BeautifulSoup(page_source, "html.parser")
        
        for script in soup(["script", "style"]): # remove all javascript and stylesheet code
            script.extract()
        # get text
        text = soup.get_text()
        # break into lines and remove leading and trailing space on each
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        # drop blank lines
        data = '\n'.join(chunk for chunk in chunks if chunk)

        await browser.close()
    return data

output = await run_playwright("https://www.monster.com/jobs/l-los-angeles-ca?page=1")

# %%
output
# Out:
# 'monster.com'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613")
structured_schema = {
    "properties": {
        "job_name": {"type": "string"},
        "posted_date": {"type": "string"}
    },
    "required": ["job_name", "posted_date"],
}
extraction_chain = create_extraction_chain(structured_schema, llm)
extraction_chain.run(output)
# Out:
# [{'job_name': 'monster.com'}]

# %%
async def run_playwright(site):
    data = ""
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)

        page = await browser.new_page()
        await page.goto(site)

        page_source = await page.content()
        soup = BeautifulSoup(page_source, "html.parser")
        
        for script in soup(["script", "style"]): # remove all javascript and stylesheet code
            script.extract()
        # get text
        text = soup.get_text()
        # break into lines and remove leading and trailing space on each
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        # drop blank lines
        data = '\n'.join(chunk for chunk in chunks if chunk)

        await browser.close()
    return data

output = await run_playwright("https://financialservices.house.gov/about/members.htm")

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613")
structured_schema = {
    "properties": {
        "member_name": {"type": "string"},
        "state": {"type": "string"},
    },
    "required": ["member_name", "state"],
}
extraction_chain = create_extraction_chain(structured_schema, llm)
extraction_chain.run(output)
# Out:
# [{'member_name': 'Patrick McHenry', 'state': 'North Carolina'},
#  {'member_name': 'Frank D. Lucas', 'state': 'Oklahoma'},
#  {'member_name': 'Pete Sessions', 'state': 'Texas'},
#  {'member_name': 'Bill Posey', 'state': 'Florida'},
#  {'member_name': 'Blaine Luetkemeyer', 'state': 'Missouri'},
#  {'member_name': 'Bill Huizenga', 'state': 'Michigan'},
#  {'member_name': 'Ann Wagner', 'state': 'Missouri'},
#  {'member_name': 'Andy Barr', 'state': 'Kentucky'},
#  {'member_name': 'Roger Williams', 'state': 'Texas'},
#  {'member_name': 'French Hill', 'state': 'Arkansas'},
#  {'member_name': 'Tom Emmer', 'state': 'Minnesota'},
#  {'member_name': 'Barry Loudermilk', 'state': 'Georgia'},
#  {'member_name': 'Alexander X. Mooney', 'state': 'West Virginia'},
#  {'member_name': 'Warren Davidson', 'state': 'Ohio'},
#  {'member_name': 'John Rose', 'state': 'Tennessee'},
#  {'member_name': 'Bryan Steil', 'state': 'Wisconsin'},
#  {'member_name': 'William Timmons', 'state': 'South Carolina'},
#  {'member_name': 'Ralph Norman', 'state': 'South Carolina'},
#  {'member_name': 'Dan Meuser', 'state': 'Pennsylvania'},
#  {'member_name': 'Scott Fitzgerald', 'state': 'Wisconsin'},
#  {'member_name': 'Andrew Garbarino', 'state': 'New York'},
#  {'member_name': 'Young Kim', 'state': 'California'},
#  {'member_name': 'Byron Donalds', 'state': 'Florida'},
#  {'member_name': 'Mike Flood', 'state': 'Nebraska'},
#  {'member_name': 'Mike Lawler', 'state': 'New York'},
#  {'member_name': 'Zach Nunn', 'state': 'Iowa'},
#  {'member_name': 'Monica De La Cruz', 'state': 'Texas'},
#  {'member_name': 'Erin Houchin', 'state': 'Indiana'},
#  {'member_name': 'Andy Ogles', 'state': 'Tennessee'},
#  {'member_name': 'Maxine Waters', 'state': 'California'},
#  {'member_name': 'Nydia M. Velázquez', 'state': 'New York'},
#  {'member_name': 'Brad Sherman', 'state': 'California'},
#  {'member_name': 'Gregory W. Meeks', 'state': 'New York'},
#  {'member_name': 'David Scott', 'state': 'Georgia'},
#  {'member_name': 'Stephen F. Lynch', 'state': 'Massachusetts'},
#  {'member_name': 'Al Green', 'state': 'Texas'},
#  {'member_name': 'Emanuel Cleaver, II', 'state': 'Missouri'},
#  {'member_name': 'Jim A. Himes', 'state': 'Connecticut'},
#  {'member_name': 'Bill Foster', 'state': 'Illinois'},
#  {'member_name': 'Joyce Beatty', 'state': 'Ohio'},
#  {'member_name': 'Juan Vargas', 'state': 'California'},
#  {'member_name': 'Josh Gottheimer', 'state': 'New Jersey'},
#  {'member_name': 'Vicente Gonzalez', 'state': 'Texas'},
#  {'member_name': 'Sean Casten', 'state': 'Illinois'},
#  {'member_name': 'Ayanna Pressley', 'state': 'Massachusetts'},
#  {'member_name': 'Steven Horsford', 'state': 'Nevada'},
#  {'member_name': 'Rashida Tlaib', 'state': 'Michigan'},
#  {'member_name': 'Ritchie Torres', 'state': 'New York'},
#  {'member_name': 'Sylvia Garcia', 'state': 'Texas'},
#  {'member_name': 'Nikema Williams', 'state': 'Georgia'},
#  {'member_name': 'Wiley Nickel', 'state': 'North Carolina'},
#  {'member_name': 'Brittany Pettersen', 'state': 'Colorado'}]

# %%
data = [{'member_name': 'Patrick McHenry', 'state': 'North Carolina'},
 {'member_name': 'Frank D. Lucas', 'state': 'Oklahoma'},
 {'member_name': 'Pete Sessions', 'state': 'Texas'},
 {'member_name': 'Bill Posey', 'state': 'Florida'},
 {'member_name': 'Blaine Luetkemeyer', 'state': 'Missouri'},
 {'member_name': 'Bill Huizenga', 'state': 'Michigan'},
 {'member_name': 'Ann Wagner', 'state': 'Missouri'},
 {'member_name': 'Andy Barr', 'state': 'Kentucky'},
 {'member_name': 'Roger Williams', 'state': 'Texas'},
 {'member_name': 'French Hill', 'state': 'Arkansas'},
 {'member_name': 'Tom Emmer', 'state': 'Minnesota'},
 {'member_name': 'Barry Loudermilk', 'state': 'Georgia'},
 {'member_name': 'Alexander X. Mooney', 'state': 'West Virginia'},
 {'member_name': 'Warren Davidson', 'state': 'Ohio'},
 {'member_name': 'John Rose', 'state': 'Tennessee'},
 {'member_name': 'Bryan Steil', 'state': 'Wisconsin'},
 {'member_name': 'William Timmons', 'state': 'South Carolina'},
 {'member_name': 'Ralph Norman', 'state': 'South Carolina'},
 {'member_name': 'Dan Meuser', 'state': 'Pennsylvania'},
 {'member_name': 'Scott Fitzgerald', 'state': 'Wisconsin'},
 {'member_name': 'Andrew Garbarino', 'state': 'New York'},
 {'member_name': 'Young Kim', 'state': 'California'},
 {'member_name': 'Byron Donalds', 'state': 'Florida'},
 {'member_name': 'Mike Flood', 'state': 'Nebraska'},
 {'member_name': 'Mike Lawler', 'state': 'New York'},
 {'member_name': 'Zach Nunn', 'state': 'Iowa'},
 {'member_name': 'Monica De La Cruz', 'state': 'Texas'},
 {'member_name': 'Erin Houchin', 'state': 'Indiana'},
 {'member_name': 'Andy Ogles', 'state': 'Tennessee'},
 {'member_name': 'Maxine Waters', 'state': 'California'},
 {'member_name': 'Nydia M. Velázquez', 'state': 'New York'},
 {'member_name': 'Brad Sherman', 'state': 'California'},
 {'member_name': 'Gregory W. Meeks', 'state': 'New York'},
 {'member_name': 'David Scott', 'state': 'Georgia'},
 {'member_name': 'Stephen F. Lynch', 'state': 'Massachusetts'},
 {'member_name': 'Al Green', 'state': 'Texas'},
 {'member_name': 'Emanuel Cleaver, II', 'state': 'Missouri'},
 {'member_name': 'Jim A. Himes', 'state': 'Connecticut'},
 {'member_name': 'Bill Foster', 'state': 'Illinois'},
 {'member_name': 'Joyce Beatty', 'state': 'Ohio'},
 {'member_name': 'Juan Vargas', 'state': 'California'},
 {'member_name': 'Josh Gottheimer', 'state': 'New Jersey'},
 {'member_name': 'Vicente Gonzalez', 'state': 'Texas'},
 {'member_name': 'Sean Casten', 'state': 'Illinois'},
 {'member_name': 'Ayanna Pressley', 'state': 'Massachusetts'},
 {'member_name': 'Steven Horsford', 'state': 'Nevada'},
 {'member_name': 'Rashida Tlaib', 'state': 'Michigan'},
 {'member_name': 'Ritchie Torres', 'state': 'New York'},
 {'member_name': 'Sylvia Garcia', 'state': 'Texas'},
 {'member_name': 'Nikema Williams', 'state': 'Georgia'},
 {'member_name': 'Wiley Nickel', 'state': 'North Carolina'},
 {'member_name': 'Brittany Pettersen', 'state': 'Colorado'}]

# %%
from collections import Counter

def find_most_potentially_corrupt_states(data):
    state_counts = Counter(item['state'] for item in data)
    most_common_state, count = state_counts.most_common(1)[0]
    print("Most common state:", most_common_state)
    print("Congress ppl with potential to become corrupted", count)

# %%
find_most_potentially_corrupt_states(data)
# Out:
# Most common state: Texas
# Congress ppl with potential to become corrupted 6
